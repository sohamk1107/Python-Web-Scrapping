# %% [markdown]
# # Web Scrapping

# %%
#https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/p/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&fm=productRecommendation%2Fsimilar&iid=R%3As%3Bp%3ASMWGEH7VGYMGCP3V%3Bl%3ALSTSMWGEH7VGYMGCP3VWUYKLZ%3Bpt%3App%3Buid%3A35e8dc43-9ef6-11ed-b7be-57bec21428e0%3B.SMWGHYF5FXGPBV6A&ppt=pp&ppn=pp&ssid=c8vbsstkw00000001674900278881&otracker=pp_reco_Similar%2BProducts_1_34.productCard.PMU_HORIZONTAL_boAt%2BStorm%2Bcall%2B1.69%2Binch%2BHD%2Bdisplay%2Bwith%2Bbluetooth%2Bcalling%2Band%2B550%2Bnits%2Bbrightness%2BSmartwatch_SMWGHYF5FXGPBV6A_productRecommendation%2Fsimilar_0&otracker1=pp_reco_PINNED_productRecommendation%2Fsimilar_Similar%2BProducts_GRID_productCard_cc_1_NA_view-all&cid=SMWGHYF5FXGPBV6A

# %%
#pip install bs4

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
url = 'https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/p/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&fm=productRecommendation%2Fsimilar&iid=R%3As%3Bp%3ASMWGEH7VGYMGCP3V%3Bl%3ALSTSMWGEH7VGYMGCP3VWUYKLZ%3Bpt%3App%3Buid%3A35e8dc43-9ef6-11ed-b7be-57bec21428e0%3B.SMWGHYF5FXGPBV6A&ppt=pp&ppn=pp&ssid=c8vbsstkw00000001674900278881&otracker=pp_reco_Similar%2BProducts_1_34.productCard.PMU_HORIZONTAL_boAt%2BStorm%2Bcall%2B1.69%2Binch%2BHD%2Bdisplay%2Bwith%2Bbluetooth%2Bcalling%2Band%2B550%2Bnits%2Bbrightness%2BSmartwatch_SMWGHYF5FXGPBV6A_productRecommendation%2Fsimilar_0&otracker1=pp_reco_PINNED_productRecommendation%2Fsimilar_Similar%2BProducts_GRID_productCard_cc_1_NA_view-all&cid=SMWGHYF5FXGPBV6A'

# %%
r = requests.get(url)

# %%
htmlcontent = r.content

# %%
htmlcontent
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
soup=bs(htmlcontent,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %% [markdown]
# # Title

# %%
soup.title
# Out:
# <title>boAt Storm call 1.69 inch HD display with bluetooth calling and 550 nits brightness Smartwatch Price in India - Buy boAt Storm call 1.69 inch HD display with bluetooth calling and 550 nits brightness Smartwatch online at Flipkart.com</title>

# %%
title = soup.title

# %%
print(title.string)
# Out:
# boAt Storm call 1.69 inch HD display with bluetooth calling and 550 nits brightness Smartwatch Price in India - Buy boAt Storm call 1.69 inch HD display with bluetooth calling and 550 nits brightness Smartwatch online at Flipkart.com

# %% [markdown]
# # Checking price of the product

# %%
price = soup.find_all('div',class_= "_30jeq3 _16Jk6d")

# %%
price                                                #After discount
# Out:
# [<div class="_30jeq3 _16Jk6d">₹1,799</div>]

# %%
product_price = []

for i in range(0,len(price)):
    product_price.append(price[i].get_text())

# %%
product_price
# Out:
# ['₹1,799']

# %% [markdown]
# # Getting all the customer Names

# %%
names=soup.find_all('p',class_="_2sc7ZR _2V5EHH")
names
# Out:
# [<p class="_2sc7ZR _2V5EHH">Radheshyam  Bishi</p>,
#  <p class="_2sc7ZR _2V5EHH">YATHARTH  RAGHUVANSHI </p>,
#  <p class="_2sc7ZR _2V5EHH">Sohan Gazi</p>,
#  <p class="_2sc7ZR _2V5EHH">Sarvagya  Jain</p>,
#  <p class="_2sc7ZR _2V5EHH">Samiran  Bhattacharjee </p>,
#  <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>,
#  <p class="_2sc7ZR _2V5EHH">Sricharan Tirlangi</p>,
#  <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>,
#  <p class="_2sc7ZR _2V5EHH">Rohit Kumar</p>,
#  <p class="_2sc7ZR _2V5EHH">ganapati dash</p>]

# %%
custom_names = []

for i in range(0,len(names)):
    custom_names.append(names[i].get_text())

# %%
custom_names
# Out:
# ['Radheshyam  Bishi',
#  'YATHARTH  RAGHUVANSHI ',
#  'Sohan Gazi',
#  'Sarvagya  Jain',
#  'Samiran  Bhattacharjee ',
#  'Flipkart Customer',
#  'Sricharan Tirlangi',
#  'Flipkart Customer',
#  'Rohit Kumar',
#  'ganapati dash']

# %% [markdown]
# # Getting all the comments by customers

# %%
comments=soup.find_all('p',class_="_2-N8zT")
comments
# Out:
# [<p class="_2-N8zT">Nice</p>,
#  <p class="_2-N8zT">Great product</p>,
#  <p class="_2-N8zT">Best in the market!</p>,
#  <p class="_2-N8zT">Fabulous!</p>,
#  <p class="_2-N8zT">Perfect product!</p>,
#  <p class="_2-N8zT">Value-for-money</p>,
#  <p class="_2-N8zT">Just wow!</p>,
#  <p class="_2-N8zT">Worth every penny</p>,
#  <p class="_2-N8zT">Highly recommended</p>,
#  <p class="_2-N8zT">Worth every penny</p>]

# %%
custom_comments = []
for i in range(0,len(comments)):
    custom_comments.append(comments[i].get_text())

# %%
custom_comments
# Out:
# ['Nice',
#  'Great product',
#  'Best in the market!',
#  'Fabulous!',
#  'Perfect product!',
#  'Value-for-money',
#  'Just wow!',
#  'Worth every penny',
#  'Highly recommended',
#  'Worth every penny']

# %% [markdown]
# # Stars given by customers

# %%
custom_stars =soup.find_all('div', class_="_3LWZlK _1BLPMq")
custom_stars
# Out:
# [<div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>]

# %%
#cust_stars = fin(class_="_3LWZlK _1BLPMq")
cust_stars=[]
for i in range(0,len(custom_stars)):
       cust_stars.append(custom_stars[i].get_text())

# %%
cust_stars
# Out:
# ['3', '5', '5', '5', '5', '4', '5', '5', '5', '5']

# %% [markdown]
# # Reviews of Customers

# %%
reviews = soup.find_all('div',class_="t-ZTKy")
reviews
# Out:
# [<div class="t-ZTKy"><div><div class=""># Display is not good but ok<br/>#Battery is ok not good <br/>AND Others features are vary good and Osm</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Over all it is a perfect smarwatch 🥰🤩<br/>- value for money🤑 <br/>- design and built quality products is best 😘 <br/>-display is also very good😊 <br/>- the product package comes is in better condition😀 and all things are very good 😇😇</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Highly Recommend 💜💖<br/><br/>Totally amazing &amp; very good quality. Overall nice feature, I like it.  Calling function is fantastic, worth of money. <br/><br/>I am very happy,  Thanks Flipkart and boAt ❤️</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
# ...

# %%
cust_reviews = []
for i in range(0,len(reviews)):
    cust_reviews.append(reviews[i].get_text())

# %%
cust_reviews
# Out:
# ['# Display is not good but ok#Battery is ok not good AND Others features are vary good and OsmREAD MORE',
#  'Over all it is a perfect smarwatch 🥰🤩- value for money🤑 - design and built quality products is best 😘 -display is also very good😊 - the product package comes is in better condition😀 and all things are very good 😇😇READ MORE',
#  'Highly Recommend 💜💖Totally amazing & very good quality. Overall nice feature, I like it.  Calling function is fantastic, worth of money. I am very happy,  Thanks Flipkart and boAt ❤️READ MORE',
#  'Superb quality watch by boat in best prices as compared to others brand 1 sound is awesome2 high brightness3 best metal display 4 the brand boat 😊5 calling features and music control is good All over love the watch , thank u boatREAD MORE',
#  'Beautiful smart watch thank u boat ❤️. Best features are available in this smart watchREAD MORE',
# ...

# %% [markdown]
# # Arranging Data in Tabular Format

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['Customer Names'] = custom_names
df['Customer Comments'] = custom_comments
df['Stars'] = cust_stars
df['Reviews'] = cust_reviews

# %%
df
# Out:
#             Customer Names    Customer Comments Stars  \
# 0        Radheshyam  Bishi                 Nice     3
# 1   YATHARTH  RAGHUVANSHI         Great product     5
# 2               Sohan Gazi  Best in the market!     5
# 3           Sarvagya  Jain            Fabulous!     5
# 4  Samiran  Bhattacharjee      Perfect product!     5
# 5        Flipkart Customer      Value-for-money     4
# 6       Sricharan Tirlangi            Just wow!     5
# 7        Flipkart Customer    Worth every penny     5
# 8              Rohit Kumar   Highly recommended     5
# 9            ganapati dash    Worth every penny     5
#
#                                              Reviews
# 0  # Display is not good but ok#Battery is ok not...
# 1  Over all it is a perfect smarwatch 🥰🤩- value f...
# 2  Highly Recommend 💜💖Totally amazing & very good...
# 3  Superb quality watch by boat in best prices as...
# 4  Beautiful smart watch thank u boat ❤️. Best fe...
# ...

# %% [raw]
# https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page=1

# %% [raw]
# https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page=40

# %%
iurl='https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page='

# %%
urls=[]
for i in range(1,783):
    urls.append(iurl+str(i))

# %%
urls
# Out:
# ['https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page=1',
#  'https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page=2',
#  'https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page=3',
#  'https://www.flipkart.com/boat-storm-call-1-69-inch-hd-display-bluetooth-calling-550-nits-brightness-smartwatch/product-reviews/itmf70a25b4a16e9?pid=SMWGHYF5FXGPBV6A&lid=LSTSMWGHYF5FXGPBV6AMEEQAX&marketplace=FLIPKART&page=4',
# ...

# %%
product_price = []
custom_names = []
custom_comments = []
cust_stars = []
cust_reviews = []

# %%
def boatscrap(u):
    for i in u:
        url=i
        r = requests.get(url)
        htmlcontent = r.content
        soup.title
        title = soup.title
    
        price = soup.find_all('div',class_= "_30jeq3 _16Jk6d")
  
    

        for i in range(0,len(price)):
            product_price.append(price[i].get_text())
        
        
        names=soup.find_all('p',class_="_2sc7ZR _2V5EHH")
        
    

        for i in range(0,len(names)):
            custom_names.append(names[i].get_text())
        
        comments=soup.find_all('p',class_="_2-N8zT")
        

        for i in range(0,len(comments)):
            custom_comments.append(comments[i].get_text())
        
        custom_stars =soup.find_all('div', class_="_3LWZlK _1BLPMq")
        
        
        for i in range(0,len(custom_stars)):
               cust_stars.append(custom_stars[i].get_text())
        
        reviews = soup.find_all('div',class_="t-ZTKy")
    
        
        
        for i in range(0,len(reviews)):
            cust_reviews.append(reviews[i].get_text())

# %%
boatscrap(urls)

# %%
product_price
# Out:
# ['₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
#  '₹1,799',
# ...

# %%
len(custom_names)
# Out:
# 16220

# %%
len(custom_comments)
# Out:
# 16220

# %%
len(cust_stars)
# Out:
# 16220

# %%
len(cust_reviews)
# Out:
# 16220

# %%
cust_stars
# Out:
# ['3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
# ...

# %%
cust_reviews
# Out:
# ['# Display is not good but ok#Battery is ok not good AND Others features are vary good and OsmREAD MORE',
#  'Over all it is a perfect smarwatch 🥰🤩- value for money🤑 - design and built quality products is best 😘 -display is also very good😊 - the product package comes is in better condition😀 and all things are very good 😇😇READ MORE',
#  'Highly Recommend 💜💖Totally amazing & very good quality. Overall nice feature, I like it.  Calling function is fantastic, worth of money. I am very happy,  Thanks Flipkart and boAt ❤️READ MORE',
#  'Superb quality watch by boat in best prices as compared to others brand 1 sound is awesome2 high brightness3 best metal display 4 the brand boat 😊5 calling features and music control is good All over love the watch , thank u boatREAD MORE',
#  'Beautiful smart watch thank u boat ❤️. Best features are available in this smart watchREAD MORE',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['Customer Names'] = custom_names
df['Customer Comments'] = custom_comments
df['Stars'] = cust_stars
df['Reviews'] = cust_reviews

# %%
df
# Out:
#                 Customer Names    Customer Comments Stars  \
# 0            Radheshyam  Bishi                 Nice     3
# 1       YATHARTH  RAGHUVANSHI         Great product     5
# 2                   Sohan Gazi  Best in the market!     5
# 3               Sarvagya  Jain            Fabulous!     5
# 4      Samiran  Bhattacharjee      Perfect product!     5
# ...                        ...                  ...   ...
# 16215        Flipkart Customer      Value-for-money     4
# 16216       Sricharan Tirlangi            Just wow!     5
# 16217        Flipkart Customer    Worth every penny     5
# 16218              Rohit Kumar   Highly recommended     5
# 16219            ganapati dash    Worth every penny     5
#
#                                                  Reviews
# 0      # Display is not good but ok#Battery is ok not...
# 1      Over all it is a perfect smarwatch 🥰🤩- value f...
# 2      Highly Recommend 💜💖Totally amazing & very good...
# ...

# %%
df.to_csv('Reviews on BOAT Smart Watch .csv')

# %%
pwd()
# Out:
# 'C:\\Users\\soham\\Desktop\\Practice Q'
